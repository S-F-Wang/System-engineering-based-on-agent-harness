# %% [markdown]
# # Lesson 00 — Agent Loop（课程占位）
#
# > 状态：占位。此 notebook 将从 raw 实验中提炼最小、可复现的 Agent Harness 核心循环。

# %% [markdown]
# ## 学习目标
#
# 完成本课后，学习者应能够：
#
# 1. 解释 `user → assistant → tool → assistant` 消息协议。
# 2. 实现带最大轮数限制的工具调用循环。
# 3. 使用 scripted model 在离线环境验证循环。
# 4. 区分模型决策、权限策略和工具执行三个边界。

# %% [markdown]
# ## 与 Raw Notebook 的关系
#
# 主要来源：`../raw/mini_harness.ipynb` 中的 *End-to-end agent harness framework* 与 *Agent Loop* 段落。课程版不会复制其运行输出或隐藏状态。

# %% [markdown]
# ## 最小循环
#
# ```text
# append user message
#         ↓
# call model ── no tool call ──→ return answer
#         │
#         └── tool call → execute → append tool result → call model again
# ```

# %%
def run_agent_loop(prompt, model, tools, max_turns=8):
    """Lesson implementation placeholder; deliberately has no live API call."""
    raise NotImplementedError(
        "TODO: implement with a scripted model before enabling live providers"
    )

# %% [markdown]
# ## 验收标准
#
# - 普通回答在一次模型调用后返回。
# - 工具调用结果使用正确的 `tool_call_id` 回传。
# - 未知工具和无效 JSON 参数转为可观察错误。
# - 无限工具循环被 `max_turns` 终止。
# - 全部主线测试离线完成，不读取真实 API key。
